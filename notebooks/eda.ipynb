# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data/dataset_TakeHome.csv')

# %%
print(df.shape)
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        P1        P2        P3        P4        P5        P6        P7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          P8        P9  ...       P21       P22       P23       P24       P25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            P1            P2            P3            P4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  P5            P6            P7            P8            P9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Time           284807 non-null  float64
#  1   P1             284807 non-null  float64
#  2   P2             284807 non-null  float64
#  3   P3             284807 non-null  float64
#  4   P4             284807 non-null  float64
#  5   P5             284807 non-null  float64
#  6   P6             284807 non-null  float64
#  7   P7             284807 non-null  float64
#  8   P8             284807 non-null  float64
#  9   P9             284807 non-null  float64
#  10  P10            284807 non-null  float64
#  11  P11            284807 non-null  float64
#  12  P12            284807 non-null  float64
#  13  P13            284807 non-null  float64
#  14  P14            284807 non-null  float64
#  15  P15            284807 non-null  float64
# ...

# %%
nb_df = len(df)

# %%
nb_dups = df.duplicated().where(df.duplicated() == True).count()

# %%
nb_unique = len(df.drop_duplicates())

# %%
print(nb_df, nb_dups, nb_unique)
# Out:
# 284807 1081 283726

# %%
nb_df == nb_dups +   nb_unique
# Out:
# True

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (283726, 31)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Dollar_amount    12
# Time              0
# P16               0
# P28               0
# P27               0
# P26               0
# P25               0
# P24               0
# P23               0
# P22               0
# P21               0
# P20               0
# P19               0
# P18               0
# P17               0
# P15               0
# P1                0
# P14               0
# P13               0
# P12               0
# P11               0
# P10               0
# P9                0
# P8                0
# P7                0
# P6                0
# P5                0
# P4                0
# P3                0
# P2                0
# Outcome           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
len(df)
# Out:
# 283714

# %%
df.columns
# Out:
# Index(['Time', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10',
#        'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20',
#        'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'Dollar_amount',
#        'Outcome'],
#       dtype='object')

# %%
for i, col in enumerate(df.columns):
    plt.figure(i)
    ax = sns.displot(df[col])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)

# %%
plt.show()

# %%
df.corr()
# Out:
#                    Time        P1        P2        P3        P4        P5  \
# Time           1.000000  0.117912 -0.010521 -0.422052 -0.105875  0.173233
# P1             0.117912  1.000000  0.006888 -0.008101  0.002249 -0.007041
# P2            -0.010521  0.006888  1.000000  0.005276 -0.001496  0.005208
# P3            -0.422052 -0.008101  0.005276  1.000000  0.002843 -0.006859
# P4            -0.105875  0.002249 -0.001496  0.002843  1.000000  0.001744
# P5             0.173233 -0.007041  0.005208 -0.006859  0.001744  1.000000
# P6            -0.063285  0.000409 -0.000597 -0.001493 -0.000887 -0.000954
# P7             0.085356 -0.009170  0.007425 -0.011730  0.004668 -0.008709
# P8            -0.038217 -0.001178  0.002911 -0.001814  0.000893  0.001425
# P9            -0.007851  0.001828 -0.000274 -0.003583  0.002160 -0.001211
# P10            0.031052  0.000816  0.000619 -0.009630  0.002747 -0.006047
# P11           -0.248575  0.001019 -0.000621  0.002334 -0.001225  0.000414
# ...

# %%
corr_matrix = df.corr().abs()

# %%
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.1)]

print(to_drop)
# Out:
# ['P1', 'P3', 'P4', 'P5', 'P11', 'P12', 'P14', 'P15', 'P22', 'P25', 'Dollar_amount', 'Outcome']
# /var/folders/my/5jx2cxsj5psgzq45yz14kftr0000gn/T/ipykernel_16067/948660819.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(np.bool))

# %%
len(high_corr_var)
print(high_corr_var)
# Out:
# []

# %%
corr_mat=df.corr()
chosen_variable=corr_mat[abs(corr_mat["Outcome"])>0.1].index
plt.figure(figsize=(31,31))
ax = sns.heatmap(df[chosen_variable].corr(),annot=True,cmap='RdBu')

# %%
f, ax = plt.subplots(figsize=(31, 31))
dataplot = sns.heatmap(df.corr(), cmap="RdBu", annot=True)
